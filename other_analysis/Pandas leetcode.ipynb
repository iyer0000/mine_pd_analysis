# %%
# # Input: 
# World table:
# +-------------+-----------+---------+------------+--------------+
# | name        | continent | area    | population | gdp          |
# +-------------+-----------+---------+------------+--------------+
# | Afghanistan | Asia      | 652230  | 25500100   | 20343000000  |
# | Albania     | Europe    | 28748   | 2831741    | 12960000000  |
# | Algeria     | Africa    | 2381741 | 37100000   | 188681000000 |
# | Andorra     | Europe    | 468     | 78115      | 3712000000   |
# | Angola      | Africa    | 1246700 | 20609294   | 100990000000 |
# +-------------+-----------+---------+------------+--------------+
# Output: 
# +-------------+------------+---------+
# | name        | population | area    |
# +-------------+------------+---------+
# | Afghanistan | 25500100   | 652230  |
# | Algeria     | 37100000   | 2381741 |
# +-------------+------------+---------+

# %%
import pandas as pd

# %%
pd.DataFrame({'name':['agf','dfdf'],'ll':[1,2]})
# Out:
#    name  ll
# 0   agf   1
# 1  dfdf   2

# %%
df=pd.read_csv(r'D:\Data_process_input\archive\orders.csv',na_values=['Not Available','unknown'])

# %%
df.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13             NaN     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23             NaN     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31             NaN     Consumer  United States
# 11        12  2023-12-25             NaN     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.columns=df.columns.str.lower()

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent'],
#       dtype='object')

# %%
260*0.2
# Out:
# 52.0

# %%
df.head(30)
# Out:
#     order_id  order_date       ship_mode      segment        country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13             NaN     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23             NaN     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31             NaN     Consumer  United States
# 11        12  2023-12-25             NaN     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
df['discount_price']=df['list_price']*df['discount_percent']/100

# %%
df['discount_sel_price']=df['list_price']-(df['list_price']*(df['discount_percent']/100))

# %%
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df['profit_after_selling']=df['discount_sel_price']-df['cost_price']

# %%
df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True)

# %%
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount_price  discount_sel_price  \
# ...

# %%
#top 10 revenue generating products
grouped_df=df['product_id'].groupby(df['discount_sel_price']).sum().reset_index()

# %%
#top 10 revenue generating products 2nd step
grouped_df.sort_values(by=['discount_sel_price'],ascending=False).head(10)
# Out:
#      discount_sel_price       product_id
# 699             21734.4  TEC-MA-10002412
# 698             16975.0  TEC-CO-10004722
# 697             13440.0  TEC-CO-10004722
# 696             10976.0  TEC-CO-10004722
# 695              9975.0  TEC-CO-10004722
# 694              9395.5  OFF-BI-10000545
# 693              9261.0  OFF-BI-10001120
# 692              8827.0  TEC-MA-10001047
# 691              8575.0  TEC-MA-10001127
# 690              8148.0  TEC-CO-10004722

# %%
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount_price  discount_sel_price  \
# ...

# %%
#month on month comparison
#for each category,which month had highest sales

# %%
pd.DatetimeIndex(df['order_date']).year.unique()
# Out:
# Index([2023, 2022], dtype='int32', name='order_date')

# %%
pd.DatetimeIndex(df['order_date']).year.unique()
# Out:
# Index([2023, 2022], dtype='int32', name='order_date')

# %%
df.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount_price  discount_sel_price  \
# 0    Bookcases  FUR-BO-10001798         2             5.2               254.8
# ...

# %%
selected_df=df[['order_date2month','category','discount_sel_price']]

# %%
selected_df
# Out:
#      order_date2month         category  discount_sel_price
# 0             2023-03        Furniture               254.8
# 1             2023-08        Furniture               708.1
# 2             2023-01  Office Supplies                 9.5
# 3             2022-06        Furniture               940.8
# 4             2022-07  Office Supplies                19.0
# ...               ...              ...                 ...
# 9989          2023-02        Furniture                28.8
# 9990          2023-03        Furniture                86.4
# 9991          2022-08       Technology               254.8
# 9992          2022-11  Office Supplies                29.1
# 9993          2022-07  Office Supplies               232.8
#
# [9994 rows x 3 columns]

# %%
mydict={}
for _ in selected_df.values.tolist():
    #if _ in mydict:
    if _[0] in mydict and mydict[_0][0]==_[1]:
        
    mydict[str(_[0])=[_[1],_[2]]

# %%
mydict
# Out:
# {'2023-03:Furniture': [86.4],
#  '2023-08:Furniture': [456.0],
#  '2023-01:Office Supplies': [211.2],
#  '2022-06:Furniture': [144.0],
#  '2022-07:Office Supplies': [232.8],
#  '2022-03:Furniture': [264.6],
#  '2022-12:Office Supplies': [0.0],
#  '2022-01:Technology': [77.6],
#  '2023-03:Office Supplies': [9.6],
#  '2023-05:Office Supplies': [38.4],
#  '2023-12:Technology': [475.0],
#  '2022-02:Office Supplies': [105.6],
#  '2023-07:Office Supplies': [134.4],
#  '2023-11:Office Supplies': [19.0],
#  '2022-06:Office Supplies': [39.2],
#  '2023-08:Office Supplies': [29.4],
#  '2022-01:Office Supplies': [9.7],
#  '2022-10:Office Supplies': [39.2],
#  '2023-05:Furniture': [19.2],
#  '2023-02:Furniture': [28.8],
#  '2022-02:Technology': [636.5],
#  '2023-12:Furniture': [451.2],
#  '2022-08:Office Supplies': [19.2],
#  '2022-08:Furniture': [19.4],
#  '2022-11:Office Supplies': [29.1],
#  '2022-09:Office Supplies': [57.6],
#  '2022-10:Technology': [855.0],
#  '2023-07:Furniture': [9.7],
# ...

# %%
selected_df.groupby(['order_date2month'])['category']

# %%
df['order_date'],['category'],['discount_sel_price']
# Out:
# (0       2023-03-01
#  1       2023-08-15
#  2       2023-01-10
#  3       2022-06-18
#  4       2022-07-13
#             ...
#  9989    2023-02-18
#  9990    2023-03-17
#  9991    2022-08-07
#  9992    2022-11-19
#  9993    2022-07-17
#  Name: order_date, Length: 9994, dtype: object,
#  ['category'],
#  ['discount_sel_price'])

# %%
pd.DatetimeIndex(df['order_date']).month
# Out:
# Index([ 3,  8,  1,  6,  7,  3, 12,  1,  3,  5,
#        ...
#         8,  9, 11,  4, 11,  2,  3,  8, 11,  7],
#       dtype='int32', name='order_date', length=9994)

# %%
df.groupby(['category'])['discount_sel_price'].sum()
# Out:
# category
# Furniture          715340.7
# Office Supplies    693644.5
# Technology         806873.5
# Name: discount_sel_price, dtype: float64

# %%
pd.DatetimeIndex(df['ArrivalDate']).year

# %%
df['ArrivalDate'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 df['order_date'].datetime.year
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'datetime'

# %%
#--find top 5 highest selling  products in each region

# %%
temp_df=df[['region','product_id','discount_sel_price']]

# %%
temp_df

# %%
discount_df=temp_df.groupby("product_id")["discount_sel_price"].sum().reset_index().sort_values(by=['discount_sel_price'],ascending=False)

# %%
discount_df.head()
# Out:
#            product_id  discount_sel_price
# 1614  TEC-CO-10004722             59514.0
# 776   OFF-BI-10003527             26525.3
# 1642  TEC-MA-10002412             21734.4
# 80    FUR-CH-10002024             21096.2
# 691   OFF-BI-10001359             19090.2

# %%
temp_df.head()
# Out:
#   region       product_id  discount_sel_price
# 0  South  FUR-BO-10001798               254.8
# 1  South  FUR-CH-10000454               708.1
# 2   West  OFF-LA-10000240                 9.5
# 3  South  FUR-TA-10000577               940.8
# 4  South  OFF-ST-10000760                19.0

# %%
pd.merge()

# %%
merged_df=pd.merge(left=temp_df,right=discount_df,how='left',on=['product_id'],suffixes=['_left','_right'])

# %%
#merged_df.groupby("name_depart")["salary"].rank(method="dense", ascending=False)

# %%
merged_df['region_rank']=merged_df.groupby(['region'])['discount_sel_price_right'].rank(method='dense',ascending=False)

# %%
merged_df=merged_df[['region','product_id','region_rank']].drop_duplicates(keep='first')

# %%
merged_df.loc[merged_df['region_rank']<=5].sort_values(by=['region','region_rank'],ascending=[True,True])
# Out:
#        region       product_id  region_rank
# 6826  Central  TEC-CO-10004722          1.0
# 2846  Central  OFF-BI-10003527          2.0
# 1438  Central  FUR-CH-10002024          3.0
# 1896  Central  OFF-BI-10001359          4.0
# 8640  Central  OFF-BI-10000545          5.0
# 2623     East  TEC-CO-10004722          1.0
# 7280     East  OFF-BI-10003527          2.0
# 7243     East  FUR-CH-10002024          3.0
# 3459     East  OFF-BI-10001359          4.0
# 869      East  OFF-BI-10000545          5.0
# 509     South  OFF-BI-10003527          1.0
# 2697    South  TEC-MA-10002412          2.0
# 8236    South  FUR-CH-10002024          3.0
# 2848    South  OFF-BI-10001359          4.0
# 4355    South  OFF-BI-10000545          5.0
# 8153     West  TEC-CO-10004722          1.0
# 2239     West  OFF-BI-10003527          2.0
# 551      West  FUR-CH-10002024          3.0
# 335      West  TEC-CO-10001449          4.0
# 6817     West  OFF-BI-10004995          5.0

# %%
temp_df['region'].apply(lambda discount_sel_price:discount_sel_price['discount_sel_price'].nlargest(5))

# %%
df.groupby(['product_id'])['discount_sel_price'].sum()
# Out:
# product_id
# FUR-BO-10000112     805.1
# FUR-BO-10000330    1036.4
# FUR-BO-10000362    2089.4
# FUR-BO-10000468     706.1
# FUR-BO-10000711     830.9
#                     ...
# TEC-PH-10004912     493.8
# TEC-PH-10004922    1037.3
# TEC-PH-10004924      48.2
# TEC-PH-10004959     328.8
# TEC-PH-10004977    5099.0
# Name: discount_sel_price, Length: 1862, dtype: float64

# %%
df.drop(['sum_product_id'],axis=1,inplace=True)

# %%
df['sum_product_id'].unique()
# Out:
# array([nan])

# %%
df.sort_values(by=['sum_product_id'],ascending=False)
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df.dtypes
# Out:
# order_id                         int64
# order_date              datetime64[ns]
# ship_mode                       object
# segment                         object
# country                         object
# city                            object
# state                           object
# postal_code                      int64
# region                          object
# category                        object
# sub_category                    object
# product_id                      object
# quantity                         int64
# discount_price                 float64
# discount_sel_price             float64
# profit_after_selling           float64
# dtype: object

# %%
df['order_date']=pd.to_datetime(df['order_date'],format='%Y-%m-%d')

# %%
df['order_date2month']=df['order_date'].dt.to_period('M')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df['order_date2month']=df['order_date'].dt.to_period('M')
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~\miniconda3\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
import sqlalchemy as sa

# %%
engine = sa.create_engine('mssql://DESKTOP-T380RQ5/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')

# %%
conn=engine.connect()

# %%
df.head(6)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
# 5         6 2022-03-13             NaN   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
# 5      Los Angeles  California        90032   West        Furniture
#
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount_price', 'discount_sel_price',
#        'profit_after_selling'],
#       dtype='object')

# %%
df.to_sql('df_orders',con=conn,index=False,if_exists='append')
# Out:
# 38

# %%
df.head(6)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
# 5         6  2022-03-13             NaN   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
# 5      Los Angeles  California        90032   West        Furniture
#
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'quantity', 'discount_price', 'discount_sel_price',
#        'profit_after_selling'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 16)

# %%
df['Ship Mode'].isnull().sum()
# Out:
# 6
